# %% [markdown]
# <a href="https://colab.research.google.com/drive/1_89xOOfaSlVa-ma9PCQzSdt8mXf7TmqF?usp=sharing" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
df=pd.read_csv("/content/dataset2.csv")
df.head()
# Out:
#    Acedamic percentage in Operating Systems  percentage in Algorithms  \
# 0                                        69                        63
# 1                                        78                        62
# 2                                        71                        86
# 3                                        76                        87
# 4                                        92                        62
#
#    Percentage in Programming Concepts  Percentage in Software Engineering  \
# 0                                  78                                  87
# 1                                  73                                  60
# 2                                  91                                  87
# 3                                  60                                  84
# 4                                  90                                  67
#
#    Percentage in Computer Networks  Percentage in Electronics Subjects  \
# ...

# %%
import pandas as  pd
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
df.set_index("Acedamic percentage in Operating Systems", inplace= True)

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(df.corr(), annot=True, cmap="YlGnBu", linewidth=.5, ax=ax)
plt.show()
# Out:
# <ipython-input-4-1ea27fa21ab3>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True, cmap="YlGnBu", linewidth=.5, ax=ax)

# %%
df.head()
# Out:
#                                           percentage in Algorithms  \
# Acedamic percentage in Operating Systems
# 69                                                              63
# 78                                                              62
# 71                                                              86
# 76                                                              87
# 92                                                              62
#
#                                           Percentage in Programming Concepts  \
# Acedamic percentage in Operating Systems
# 69                                                                        78
# 78                                                                        73
# 71                                                                        91
# 76                                                                        60
# 92                                                                        90
#
# ...

# %%
import seaborn as sns
sns.set(style="darkgrid")
g = sns.catplot(x="certifications",col="Suggested Job Role",
                data=df, kind="count"
                );

# %%
import seaborn as sns
sns.set(style="darkgrid")
g = sns.catplot(x="Interested subjects",col="Suggested Job Role",
                data=df, kind="count"
                );

# %%
import seaborn as sns
sns.set(style="darkgrid")
g = sns.catplot(x="Suggested Job Role",col="Interested subjects",
                data=df.head(4), kind="count"
                );

# %%
sns.catplot(data=df, x="Suggested Job Role", y="hackathons", kind="swarm")
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 98.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 98.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 99.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 98.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# Error in callback <function flush_figures at 0x78acecc04160> (for post_execute):
# ...

# %%
plt.figure(figsize=(15,20))
sns.boxplot(x='Suggested Job Role', y='hackathons', data=df)
# Out:
# <Axes: xlabel='Suggested Job Role', ylabel='hackathons'>
